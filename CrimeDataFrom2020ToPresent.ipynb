# %% [markdown]
# <a href="https://colab.research.google.com/github/Yarin-Abdulaziz/Airline-Booking-System/blob/main/CrimeDataFrom2020ToPresent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Yarin Aldaheri - Crime_Data_from_2020_to_Present
from google.colab import files
import pandas as pd

uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])
df.head()
# Out:
#      <input type="file" id="files-47a417cb-5897-40a1-85b7-1c8b3df60196" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47a417cb-5897-40a1-85b7-1c8b3df60196">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
sns.set_palette("muted")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv("Crime_Data_from_2020_to_Present.csv")
data.sample(2)
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 536701  221000828  08/12/2022 12:00:00 AM  08/12/2022 12:00:00 AM      1340
# 662621  231613315  10/24/2023 12:00:00 AM  10/24/2023 12:00:00 AM      2120
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd     Crm Cd Desc  \
# 536701    10  West Valley         1041         1     310        BURGLARY
# 662621    16     Foothill         1651         2     922  CHILD STEALING
#
#                                         Mocodes  Vict Age Vict Sex  \
# 536701  0344 1822 0216 0358 0329 1202 0209 1420        73        M
# 662621                      0913 1258 0553 2004        11        F
#
#        Vict Descent  Premis Cd                                   Premis Desc  \
# 536701            W      501.0                        SINGLE FAMILY DWELLING
# 662621            H      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
#
# ...

# %%
data.shape
# Out:
# (1004991, 28)

# %%
data.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
print(data["Status Desc"].unique(), "\n----------------------------------------",data["Status"].unique())
# Out:
# ['Invest Cont' 'Adult Other' 'Adult Arrest' 'Juv Arrest' 'Juv Other' 'UNK']
# ---------------------------------------- ['IC' 'AO' 'AA' 'JA' 'JO' 'CC' nan]

# %%
CrmData = data [["Crm Cd 1", "Crm Cd 2", "Crm Cd 3", "Crm Cd 4"]]
print(CrmData.isnull().sum(), "will be deleted")

plt.figure(figsize=(15, 15))
sns.heatmap(CrmData.notnull(), yticklabels=False, cmap='viridis')

plt.show()
# Out:
# Crm Cd 1         11
# Crm Cd 2     935831
# Crm Cd 3    1002677
# Crm Cd 4    1004927
# dtype: int64 will be deleted

# %%
data.drop(columns={'DR_NO', 'AREA', 'Rpt Dist No', 'Crm Cd','Premis Cd'
                   , 'Premis Desc', 'Weapon Used Cd', 'Status', 'Cross Street'
                   , 'LAT','LON', 'Mocodes', 'Crm Cd 1','Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4'}, inplace=True)

# %%
data.sample(2)
# Out:
#                      Date Rptd                DATE OCC  TIME OCC    AREA NAME  \
# 470830  05/10/2022 12:00:00 AM  05/10/2022 12:00:00 AM       330  77th Street
# 795799  04/23/2023 12:00:00 AM  04/23/2023 12:00:00 AM        42      Topanga
#
#         Part 1-2                            Crm Cd Desc  Vict Age Vict Sex  \
# 470830         1  INTIMATE PARTNER - AGGRAVATED ASSAULT        24        F
# 795799         2               BATTERY - SIMPLE ASSAULT        27        M
#
#        Vict Descent                                     Weapon Desc  \
# 470830            B  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 795799            H  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
#
#         Status Desc                                  LOCATION
# 470830  Adult Other    900 W  80TH                         ST
# 795799  Invest Cont  21900    LANARK                       ST

# %%
data.shape
# Out:
# (1004991, 12)

# %%
data.rename(columns={"Date Rptd":"notifiction_date", "DATE OCC": "crime_date", "TIME OCC": "accident_time"
                     , "AREA NAME": "area", "LOCATION": "location"
                     , "Part 1-2": "level", "Crm Cd Desc":"description_crime"
                     , "Vict Age":"vict_age", "Vict Sex":"vict_sex", "Vict Descent":"vict_descent"
                     , "Weapon Desc": "weapon_used", "Status Desc": "status"}, inplace=True)

# %%
data.sample(2)
# Out:
#               notifiction_date              crime_date  accident_time  \
# 475456  05/11/2022 12:00:00 AM  05/11/2022 12:00:00 AM           2130
# 878618  04/17/2024 12:00:00 AM  04/17/2024 12:00:00 AM           1430
#
#                area  level                      description_crime  vict_age  \
# 475456  77th Street      1                    BURGLARY, ATTEMPTED        25
# 878618      Mission      1  INTIMATE PARTNER - AGGRAVATED ASSAULT        29
#
#        vict_sex vict_descent                                     weapon_used  \
# 475456        M            H                                             NaN
# 878618        F            H  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
#
#              status                                 location
# 475456  Invest Cont  1500 W  59TH                         ST
# 878618  Adult Other  8500    CEDROS                       AV

# %%
data["area"].unique()
# Out:
# array(['N Hollywood', 'Van Nuys', 'Wilshire', 'Pacific', 'Hollenbeck',
#        'Southwest', 'Northeast', 'Devonshire', 'Topanga', 'Hollywood',
#        'Olympic', 'Southeast', 'Newton', 'Foothill', 'Mission', 'Rampart',
#        'Central', 'West LA', '77th Street', 'West Valley', 'Harbor'],
#       dtype=object)

# %%
data["level"].unique()
# Out:
# array([2, 1])

# %%
data["vict_descent"].unique()
# Out:
# array(['H', 'W', 'A', 'B', nan, 'X', 'O', 'C', 'J', 'V', 'K', 'F', 'I',
#        'Z', 'L', 'G', 'P', 'D', 'U', 'S', '-'], dtype=object)

# %%
data[data["vict_descent"] == "-"]
# Out:
#               notifiction_date              crime_date  accident_time  \
# 756243  04/12/2023 12:00:00 AM  03/30/2023 12:00:00 AM           1200
# 807776  06/29/2023 12:00:00 AM  06/29/2023 12:00:00 AM           2115
#
#             area  level                                  description_crime  \
# 756243  Van Nuys      2                   DOCUMENT FORGERY / STOLEN FELONY
# 807776   Olympic      2  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#         vict_age vict_sex vict_descent weapon_used       status  \
# 756243        38        M            -         NaN  Invest Cont
# 807776         0        -            -         NaN  Invest Cont
#
#                                         location
# 756243  15300    MAGNOLIA                     BL
# 807776   1900 S  WESTERN                      AV

# %%
data["vict_descent"].replace("-", "X", inplace=True)

# %%
CodeX = data[data["vict_descent"] == "X"]["vict_descent"].count()

print(f"Values that contain the code X: {CodeX}")
data.sample(2)
# Out:
# Values that contain the code X: 106687
#               notifiction_date              crime_date  accident_time  \
# 338126  06/29/2021 12:00:00 AM  06/29/2021 12:00:00 AM           1615
# 684576  06/17/2023 12:00:00 AM  06/14/2023 12:00:00 AM           1700
#
#               area  level                                  description_crime  \
# 338126   Hollywood      1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 684576  Devonshire      2  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#         vict_age vict_sex vict_descent    weapon_used       status  \
# 338126        19        M            B  FOLDING KNIFE  Invest Cont
# 684576        29        M            H            NaN  Invest Cont
#
#                                        location
# 338126  1300 N  WESTERN                      AV
# 684576  9300    TAMPA                        AV

# %%
data.info()
print("\n____________________________________________________\n")
data.sample(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   notifiction_date   1004991 non-null  object
#  1   crime_date         1004991 non-null  object
#  2   accident_time      1004991 non-null  int64
#  3   area               1004991 non-null  object
#  4   level              1004991 non-null  int64
#  5   description_crime  1004991 non-null  object
#  6   vict_age           1004991 non-null  int64
#  7   vict_sex           860347 non-null   object
#  8   vict_descent       860335 non-null   object
#  9   weapon_used        327247 non-null   object
#  10  status             1004991 non-null  object
#  11  location           1004991 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 92.0+ MB
#
# ____________________________________________________
# ...

# %%
print(data.isnull().sum())
plt.figure(figsize=(20, 10))
sns.heatmap(data.isnull(), yticklabels=False, cmap='viridis')

plt.show()
# Out:
# notifiction_date          0
# crime_date                0
# accident_time             0
# area                      0
# level                     0
# description_crime         0
# vict_age                  0
# vict_sex             144644
# vict_descent         144656
# weapon_used          677744
# status                    0
# location                  0
# dtype: int64

# %%
data["vict_sex"] = data["vict_sex"].map({"M": "Male", "F":"Female"})

# %%
MSData = data[data["vict_sex"] == "Male"][["vict_sex", "accident_time", "level", "vict_age"]]
MSData.sample(5)
# Out:
#        vict_sex  accident_time  level  vict_age
# 247699     Male            200      2        22
# 309740     Male           1900      2        46
# 611615     Male           1900      1        24
# 423440     Male            554      1        30
# 265630     Male           1208      1        57

# %%
FSData = data[data["vict_sex"] == "Female"][["vict_sex", "accident_time", "level", "vict_age"]]
FSData.sample(5)
# Out:
#        vict_sex  accident_time  level  vict_age
# 665691   Female           1640      1        35
# 387897   Female            930      2        60
# 51208    Female           1900      1        23
# 598344   Female           1410      2        35
# 488953   Female              1      2        27

# %%
MFData = data[["vict_sex", "accident_time", "level", "vict_age"]]
MFData.sample(5)
# Out:
#        vict_sex  accident_time  level  vict_age
# 968262      NaN           1443      1         0
# 765198      NaN              1      1         0
# 88336       NaN            700      2         0
# 678516      NaN           1830      1         0
# 876764     Male            824      1         0

# %%
MFData.groupby(["vict_sex", "level"], dropna= True)["vict_sex"].count().plot(kind="bar")
plt.show()

# %%
for index in data.index:
    if pd.isnull(data.loc[index, 'vict_sex']):
        if data.loc[index, 'level'] == 1:
            data.loc[index, 'vict_sex'] = 'Male'
        else:
            data.loc[index, 'vict_sex'] = 'Female'

# %%
data["vict_sex"].isnull().sum()
# Out:
# np.int64(0)

# %%
data.sample(10)
# Out:
#               notifiction_date              crime_date  accident_time  \
# 908946  02/20/2024 12:00:00 AM  02/16/2024 12:00:00 AM            530
# 20567   07/04/2020 12:00:00 AM  07/04/2020 12:00:00 AM            200
# 81052   08/15/2020 12:00:00 AM  08/15/2020 12:00:00 AM           2155
# 872712  05/09/2023 12:00:00 AM  02/22/2023 12:00:00 AM           2010
# 401736  04/14/2021 12:00:00 AM  03/23/2021 12:00:00 AM           1809
# 614022  08/06/2022 12:00:00 AM  08/06/2022 12:00:00 AM              9
# 89695   01/25/2020 12:00:00 AM  01/24/2020 12:00:00 AM           2130
# 258812  06/29/2021 12:00:00 AM  06/29/2021 12:00:00 AM           2245
# 731373  05/25/2023 12:00:00 AM  05/24/2023 12:00:00 AM           2000
# 4449    09/11/2020 12:00:00 AM  09/11/2020 12:00:00 AM           1035
#
#                area  level                                  description_crime  \
# 908946     Foothill      2  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# ...

# %%
data["vict_descent"].isnull().sum()
# Out:
# np.int64(144656)

# %%
data["vict_descent"].fillna("X", inplace=True)
print("\n------------------------------------------------\n", "Missing values:", data["vict_descent"].isnull().sum(), "\n------------------------------------------------\n")
data.sample(2)
# Out:
# ------------------------------------------------
#  Missing values: 0
# ------------------------------------------------
#               notifiction_date              crime_date  accident_time  \
# 597649  07/29/2022 12:00:00 AM  07/17/2022 12:00:00 AM           1015
# 532052  03/11/2022 12:00:00 AM  03/07/2022 12:00:00 AM           1000
#
#             area  level                                  description_crime  \
# 597649  Foothill      1  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 532052   Topanga      2                                 BUNCO, GRAND THEFT
#
#         vict_age vict_sex vict_descent weapon_used       status  \
# 597649         0     Male            X         NaN  Invest Cont
# 532052        80     Male            W         NaN  Invest Cont
#
#                                         location
# 597649  11500    CANTARA                      ST
# 532052   4700    LARKWOOD                     AV

# %%
data["weapon_used"].value_counts().sort_values(ascending=False).head()
# Out:
# weapon_used
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    174761
# UNKNOWN WEAPON/OTHER WEAPON                        36390
# VERBAL THREAT                                      23846
# HAND GUN                                           20182
# SEMI-AUTOMATIC PISTOL                               7267
# Name: count, dtype: int64

# %%
data["weapon_used"].fillna("Unknown", inplace=True)
print("\n------------------------------------------------\n", "Missing values:", data["weapon_used"].isnull().sum(), "\n------------------------------------------------\n")
data.sample(2)
# Out:
# ------------------------------------------------
#  Missing values: 0
# ------------------------------------------------
#               notifiction_date              crime_date  accident_time  \
# 473016  08/01/2022 12:00:00 AM  08/01/2022 12:00:00 AM           1707
# 939024  02/08/2024 12:00:00 AM  02/08/2024 12:00:00 AM           1530
#
#                area  level                       description_crime  vict_age  \
# 473016  77th Street      2                BATTERY - SIMPLE ASSAULT        36
# 939024      Topanga      2  CRIMINAL THREATS - NO WEAPON DISPLAYED        14
#
#        vict_sex vict_descent                                     weapon_used  \
# 473016   Female            B  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 939024     Male            W                                   VERBAL THREAT
#
#               status                                 location
# 473016  Adult Arrest  8800    HAAS                         AV
# ...

# %%
data["weapon_used"].value_counts().sort_values(ascending=False).head()
# Out:
# weapon_used
# Unknown                                           677744
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    174761
# UNKNOWN WEAPON/OTHER WEAPON                        36390
# VERBAL THREAT                                      23846
# HAND GUN                                           20182
# Name: count, dtype: int64

# %%
data[data["vict_age"] == 0]
# Out:
#                notifiction_date              crime_date  accident_time  \
# 12       09/06/2020 12:00:00 AM  09/05/2020 12:00:00 AM           1500
# 13       07/03/2020 12:00:00 AM  07/02/2020 12:00:00 AM            500
# 18       09/04/2020 12:00:00 AM  08/17/2020 12:00:00 AM            400
# 22       01/29/2020 12:00:00 AM  01/29/2020 12:00:00 AM            545
# 31       05/28/2020 12:00:00 AM  05/25/2020 12:00:00 AM            200
# ...                         ...                     ...            ...
# 1004978  02/05/2025 12:00:00 AM  02/05/2025 12:00:00 AM           1130
# 1004979  02/03/2025 12:00:00 AM  01/31/2025 12:00:00 AM           1800
# 1004980  03/01/2025 12:00:00 AM  02/19/2025 12:00:00 AM           1800
# 1004983  04/29/2025 12:00:00 AM  04/29/2025 12:00:00 AM            425
# 1004984  02/11/2025 12:00:00 AM  02/11/2025 12:00:00 AM            730
#
#                 area  level  \
# 12           Topanga      1
# 13        Devonshire      1
# ...

# %%
mean_age = int(np.mean(data["vict_age"]))
print("mean of age: " , mean_age)
data["vict_age"] = data["vict_age"].replace(0 , mean_age)
# data[data["vict_age"] == 0]

data["vict_age"]
# Out:
# mean of age:  28
# 0          31
# 1          32
# 2          30
# 3          47
# 4          63
#            ..
# 1004986    35
# 1004987    11
# 1004988    16
# 1004989    17
# 1004990    35
# Name: vict_age, Length: 1004991, dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(4945)

# %%
data[(data.duplicated(keep= False)) & (data["vict_age"] == 29)]
# Out:
#               notifiction_date              crime_date  accident_time  \
# 52157   10/26/2020 12:00:00 AM  10/25/2020 12:00:00 AM           1740
# 61665   08/14/2020 12:00:00 AM  08/14/2020 12:00:00 AM            100
# 63529   08/14/2020 12:00:00 AM  08/14/2020 12:00:00 AM            100
# 82959   10/26/2020 12:00:00 AM  10/25/2020 12:00:00 AM           1740
# 111721  04/12/2020 12:00:00 AM  04/12/2020 12:00:00 AM           1335
# ...                        ...                     ...            ...
# 944849  02/02/2024 12:00:00 AM  02/02/2024 12:00:00 AM            320
# 954579  03/24/2024 12:00:00 AM  03/24/2024 12:00:00 AM            845
# 956947  07/04/2024 12:00:00 AM  07/04/2024 12:00:00 AM           1330
# 980530  07/04/2024 12:00:00 AM  07/04/2024 12:00:00 AM           1330
# 994187  01/13/2024 12:00:00 AM  01/13/2024 12:00:00 AM             55
#
#                area  level                               description_crime  \
# ...

# %%
print("Duplicates Values: ", data.duplicated().sum(), "\n------------------------------------------------\n")
data.drop_duplicates(inplace=True)
print("abracadabra Done")
# Out:
# Duplicates Values:  4945
# ------------------------------------------------
#
# abracadabra Done

# %%
data.sample(5)
# Out:
#               notifiction_date              crime_date  accident_time  \
# 722903  07/19/2023 12:00:00 AM  07/18/2023 12:00:00 AM           1310
# 963719  12/06/2024 12:00:00 AM  11/27/2024 12:00:00 AM           1200
# 698005  07/23/2023 12:00:00 AM  07/23/2023 12:00:00 AM            849
# 168431  04/28/2020 12:00:00 AM  04/28/2020 12:00:00 AM            900
# 707487  02/13/2023 12:00:00 AM  02/12/2023 12:00:00 AM              1
#
#                area  level                                  description_crime  \
# 722903     Van Nuys      1                                           BURGLARY
# 963719       Newton      1  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 698005    Northeast      1                                           BURGLARY
# 168431      Central      1                                   VEHICLE - STOLEN
# 707487  77th Street      2           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
#         vict_age vict_sex vict_descent weapon_used        status  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000046 entries, 0 to 1004990
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   notifiction_date   1000046 non-null  object
#  1   crime_date         1000046 non-null  object
#  2   accident_time      1000046 non-null  int64
#  3   area               1000046 non-null  object
#  4   level              1000046 non-null  int64
#  5   description_crime  1000046 non-null  object
#  6   vict_age           1000046 non-null  int64
#  7   vict_sex           1000046 non-null  object
#  8   vict_descent       1000046 non-null  object
#  9   weapon_used        1000046 non-null  object
#  10  status             1000046 non-null  object
#  11  location           1000046 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 99.2+ MB

# %%
data["notifiction_date"].str.contains("12:00:00 AM").sum()
# Out:
# np.int64(1000046)

# %%
data["notifiction_date"] = data["notifiction_date"].str.replace("12:00:00 AM", "")
data["crime_date"] = data["crime_date"].str.replace("12:00:00 AM", "")
data.sample(5)
# Out:
#        notifiction_date   crime_date  accident_time       area  level  \
# 482865      10/21/2022   10/21/2022             820    Topanga      2
# 477890      11/22/2022   11/18/2022            2200  Northeast      1
# 209092      12/07/2021   12/06/2021            2300  Southeast      1
# 971305      05/13/2024   05/13/2024            1736  Hollywood      1
# 302438      12/15/2021   12/15/2021            1605  Southeast      1
#
#                                         description_crime  vict_age vict_sex  \
# 482865                                        COUNTERFEIT        26     Male
# 477890  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        30   Female
# 209092  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...        50     Male
# 971305           SHOPLIFTING - PETTY THEFT ($950 & UNDER)        28     Male
# 302438     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        32     Male
#
#        vict_descent      weapon_used       status  \
# ...

# %%
data["crime_date"] = pd.to_datetime(data["crime_date"])
data["notifiction_date"] = pd.to_datetime(data["notifiction_date"])

print(data.info(), "\n------------------------------------------------\n")
data.sample()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000046 entries, 0 to 1004990
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   notifiction_date   1000046 non-null  datetime64[ns]
#  1   crime_date         1000046 non-null  datetime64[ns]
#  2   accident_time      1000046 non-null  int64
#  3   area               1000046 non-null  object
#  4   level              1000046 non-null  int64
#  5   description_crime  1000046 non-null  object
#  6   vict_age           1000046 non-null  int64
#  7   vict_sex           1000046 non-null  object
#  8   vict_descent       1000046 non-null  object
#  9   weapon_used        1000046 non-null  object
#  10  status             1000046 non-null  object
#  11  location           1000046 non-null  object
# dtypes: datetime64[ns](2), int64(3), object(7)
# memory usage: 99.2+ MB
# None
# ------------------------------------------------
# ...

# %%
accident_time = []

for num in data["accident_time"]:
  if num <= 24:
    new = num * 100
    accident_time.append(new)
  elif num > 24 and num < 100:
    new2 = num * 10
    accident_time.append(new2)
  else:
    accident_time.append(num)

# %%
data['accident_time'] = accident_time
print("for Sure because this index is outbut 1 :-->", data["accident_time"][225211], "\n------------------------------------------------\n Done")
data.sample(5)
# Out:
# for Sure because this index is outbut 1 :--> 1000
# ------------------------------------------------
#  Done
#        notifiction_date crime_date  accident_time         area  level  \
# 570234       2022-11-14 2022-11-09           1630    Southeast      2
# 146916       2020-11-16 2020-11-16           1000  77th Street      2
# 558658       2022-07-26 2022-07-26           1930  West Valley      2
# 251557       2021-01-22 2021-01-22            615      West LA      2
# 124062       2020-10-13 2020-10-13            545       Harbor      2
#
#                                description_crime  vict_age vict_sex  \
# 570234  VANDALISM - MISDEAMEANOR ($399 OR UNDER)        67   Female
# 146916         INTIMATE PARTNER - SIMPLE ASSAULT        26   Female
# 558658                  BATTERY - SIMPLE ASSAULT        42     Male
# 251557                               TRESPASSING        37     Male
# 124062         INTIMATE PARTNER - SIMPLE ASSAULT        28   Female
#
# ...

# %%
print("for more Sure :-->\n")
data[data["accident_time"] == 35]
# Out:
# for more Sure :-->
# Empty DataFrame
# Columns: [notifiction_date, crime_date, accident_time, area, level, description_crime, vict_age, vict_sex, vict_descent, weapon_used, status, location]
# Index: []

# %%
data["level"].replace({1: "Serious", 2: "LessSerious"}, inplace=True)
data.sample(5)
# Out:
#        notifiction_date crime_date  accident_time         area        level  \
# 195196       2020-01-23 2020-01-22           2200       Newton      Serious
# 359966       2021-12-24 2021-12-24           1410  N Hollywood      Serious
# 27367        2020-05-08 2020-04-17           1200      Mission  LessSerious
# 918905       2024-01-31 2024-01-29           1930      Pacific      Serious
# 47396        2020-08-30 2020-08-22           1846      Pacific  LessSerious
#
#                                         description_crime  vict_age vict_sex  \
# 195196                                   VEHICLE - STOLEN        28     Male
# 359966                                           BURGLARY        20   Female
# 27367   VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        44     Male
# 918905  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        32   Female
# 47396            VANDALISM - MISDEAMEANOR ($399 OR UNDER)        29     Male
#
# ...

# %%
# data.to_csv("/content/drive/MyDrive/Crime Data from 2020 to Present/clean_data.csv")

# %%
data.sample()
# Out:
#        notifiction_date crime_date  accident_time    area        level  \
# 123574       2020-01-31 2020-01-29            100  Newton  LessSerious
#
#         description_crime  vict_age vict_sex vict_descent weapon_used  \
# 123574  THEFT OF IDENTITY        20   Female            B     Unknown
#
#              status                                location
# 123574  Invest Cont  400 E  68TH                         ST

# %%
level = data["level"].value_counts()
level
# Out:
# level
# Serious        599588
# LessSerious    400458
# Name: count, dtype: int64

# %%
area = data["area"].value_counts()
area
# Out:
# area
# Central        69171
# 77th Street    61449
# Pacific        59173
# Southwest      57126
# Hollywood      52222
# N Hollywood    50918
# Olympic        49854
# Southeast      49612
# Newton         48938
# Wilshire       48023
# Rampart        46549
# West LA        45577
# Northeast      42798
# Van Nuys       42746
# West Valley    42004
# Devonshire     41504
# Topanga        41238
# Harbor         41122
# Mission        40153
# Hollenbeck     36912
# Foothill       32957
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 10), gridspec_kw={'height_ratios': [1, 2]})

fig.suptitle("Crime Analysis by area and Level", fontsize=12)
axes[0].pie(level.values, labels=level.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title("Level")

sns.barplot(x=area.index, y=area.values, ax=axes[1])
axes[1].set_title("Area")
axes[1].set_xticklabels(area.index, rotation=90)

for i in range(len(area.index)):
    plt.text(i , area.values[i] , area.values[i]
             , ha= "center" , va= "bottom"
            , fontsize= 8)

plt.show()

# %%
common_crim = data.groupby("area")["description_crime"].value_counts().sort_values(ascending=False).head(10).reset_index(name="count")
common_crim
# Out:
#           area         description_crime  count
# 0      Central     BURGLARY FROM VEHICLE   9690
# 1  77th Street          VEHICLE - STOLEN   8720
# 2       Newton          VEHICLE - STOLEN   8202
# 3    Southeast          VEHICLE - STOLEN   7193
# 4      Central  BATTERY - SIMPLE ASSAULT   6786
# 5    Southwest          VEHICLE - STOLEN   6616
# 6      Pacific          VEHICLE - STOLEN   6425
# 7   Hollenbeck          VEHICLE - STOLEN   6149
# 8       Harbor          VEHICLE - STOLEN   6066
# 9      Mission          VEHICLE - STOLEN   6000

# %%
import plotly.express as px
import plotly.graph_objects as go
# إضافة إحداثيات للمناطق
coordinates = {
    'Central': (34.0522, -118.2437),
    '77th Street': (33.9731, -118.2827),
    'Newton': (34.0224, -118.2851),
    'Southeast': (33.9891, -118.2569),
    'Southwest': (34.0505, -118.3093),
    'Pacific': (33.9850, -118.4695),
    'Hollenbeck': (34.0384, -118.2075),
    'Harbor': (33.7866, -118.2987)
}

# إضافة الإحداثيات للDataFrame
common_crim['lat'] = common_crim['area'].map(lambda x: coordinates.get(x, (0,0))[0])
common_crim['lon'] = common_crim['area'].map(lambda x: coordinates.get(x, (0,0))[1])

# تبسيط أسماء الجرائم لسهولة العرض
common_crim['crime_type'] = common_crim['description_crime'].map({
    'BURGLARY FROM VEHICLE': 'Stealing from cars',
    'VEHICLE - STOLEN': 'Car theft',
    'BATTERY - SIMPLE ASSAULT': 'Simple assault',
    'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT': 'Serious assault'
})

# إنشاء الخريطة
fig = px.scatter_mapbox(common_crim,
                       lat='lat',
                       lon='lon',
                       size='count',  # حجم حسب العدد
                       color='crime_type',  # لون حسب نوع الجريمة
                       hover_name='area',  # اسم المنطقة عند التحويم
                       hover_data={
                           'crime_type': True,  # نوع الجريمة
                           'count': True,      # العدد
                           'lat': False,       # إخفاء خط العرض
                           'lon': False        # إخفاء خط الطول
                       },
                       size_max=50,  # الحجم الأقصى للدائرة
                       zoom=10,
                       center=dict(lat=34.0522, lon=-118.2437),
                       title='Analyzing crime in Los Angeles by type and number')

# تحسين مظهر الخريطة
fig.update_layout(
    mapbox_style='carto-positron',
    paper_bgcolor='white',
    height=800,
    # تخصيص العنوان
    title={
        'text': 'Analyzing crime in Los Angeles by type and number',
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': {'size': 24}
    },
    # تخصيص وسيلة الإيضاح
    legend_title_text='Type of crime',
    legend={
        'orientation': 'h',
        'yanchor': 'bottom',
        'y': -0.1,
        'xanchor': 'center',
        'x': 0.5
    }
)

# إضافة معلومات تفصيلية عند التحويم
fig.update_traces(
    hovertemplate="<b>Area: %{hovertext}</b><br>" +
                  "Type of offense: %{customdata[0]}<br>" +
                  "Number: %{customdata[1]}<br>"
)

# عرض الخريطة
fig.show()

# حفظ الخريطة كملف HTML تفاعلي
fig.write_html("detailed_crime_map.html")

# طباعة ملخص إحصائي
print("\nملخص إحصائي للجرائم:")
summary = common_crim.groupby('crime_type').agg({
    'count': ['sum', 'mean', 'count']
}).round(2)
print(summary)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
common_crim[common_crim["description_crime"] == "VEHICLE - STOLEN"]["count"].sum()
# Out:
# np.int64(55371)

# %%
common_crim.set_index("area")["count"].plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
plt.title("Common Crims in Each Area")
plt.ylabel("")
plt.legend(labels = common_crim["description_crime"], loc="upper left", bbox_to_anchor=(1.2, 1))
plt.show()

# %%
data["range_time"] = pd.cut(data["accident_time"]
                            , bins= [0, 600, 1200, 1800, 2400]
                            , labels= ['Morning', 'Afternoon', 'Evening', 'Night']
                            , right= False)
data.sample()
# Out:
#       notifiction_date crime_date  accident_time         area    level  \
# 94019       2020-09-14 2020-09-14            200  77th Street  Serious
#
#                                     description_crime  vict_age vict_sex  \
# 94019  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        15   Female
#
#       vict_descent weapon_used       status                         location  \
# 94019            H    HAND GUN  Invest Cont  74TH                         ST
#
#       range_time
# 94019    Morning

# %%
range_time = data["range_time"].value_counts().sort_values(ascending= False).reset_index(name = "count")
range_time
# Out:
#   range_time   count
# 0    Evening  328098
# 1      Night  314307
# 2  Afternoon  211313
# 3    Morning  146252

# %%
print(range_time)

plt.figure(figsize=(10, 5))

sns.barplot(x=range_time["range_time"], y=range_time["count"], order= range_time["range_time"])
plt.title("The common times when the crime")
plt.xlabel("Time")
plt.ylabel("")

plt.show()
# Out:
#   range_time   count
# 0    Evening  328098
# 1      Night  314307
# 2  Afternoon  211313
# 3    Morning  146252

# %%
relation = data[["vict_sex", "description_crime", "level"]]
relation
# Out:
#         vict_sex                                  description_crime  \
# 0           Male                                  THEFT OF IDENTITY
# 1           Male     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2           Male                                  THEFT OF IDENTITY
# 3         Female  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4           Male    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...          ...                                                ...
# 1004986     Male                          OTHER MISCELLANEOUS CRIME
# 1004987     Male                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988   Female                                  INDECENT EXPOSURE
# 1004989     Male                           BATTERY - SIMPLE ASSAULT
# 1004990   Female                                  INDECENT EXPOSURE
#
#                level
# 0        LessSerious
# 1            Serious
# 2        LessSerious
# 3            Serious
# 4            Serious
# ...

# %%
desc = relation.groupby("vict_sex")["description_crime"].count()
print("The ages of victims of all kinds who have been subjected to types of audacity:\n", desc)

desc.plot(kind="bar")
plt.xticks(rotation=0)
plt.xlabel("Sex")

plt.show()
# Out:
# The ages of victims of all kinds who have been subjected to types of audacity:
#  vict_sex
# Female    397637
# Male      602409
# Name: description_crime, dtype: int64

# %%
rel_level = relation.groupby("vict_sex")["level"].value_counts().reset_index(name ="count")
rel_level
# Out:
#   vict_sex        level   count
# 0   Female  LessSerious  239222
# 1   Female      Serious  158415
# 2     Male      Serious  441173
# 3     Male  LessSerious  161236

# %%
g = sns.catplot(
    kind="bar",
    x="vict_sex",
    y= "count",
    hue="level",
    data=rel_level,
    errorbar="sd",
    palette="dark",
    alpha=0.6,
    height=6,
    order=["Male", "Female"]
)

plt.xlabel("Sex")
plt.ylabel("")
plt.title("Relationship between sex and level")
plt.show()

# %%
weapon = data[(data["weapon_used"] != "Unknown") & (data["level"] == "Serious")]
weapon.head()
# Out:
#    notifiction_date crime_date  accident_time         area    level  \
# 1        2020-10-21 2020-10-18           1845  N Hollywood  Serious
# 19       2020-01-19 2020-01-19           1850      Pacific  Serious
# 24       2020-04-28 2020-04-28           1730     Foothill  Serious
# 28       2020-12-15 2020-12-15           1111      Mission  Serious
# 35       2020-06-18 2020-04-26           1908      Mission  Serious
#
#                                  description_crime  vict_age vict_sex  \
# 1   ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        32     Male
# 19                                        BURGLARY        37     Male
# 24  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        14     Male
# 28                                         ROBBERY        19     Male
# 35  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        19     Male
#
#    vict_descent                       weapon_used        status  \
# 1             H  KNIFE WITH BLADE 6INCHES OR LESS   Invest Cont
# ...

# %%
weapon_data = weapon["weapon_used"].value_counts().sort_values(ascending= False).head(10).reset_index(name="count")
weapon_data
# Out:
#                                       weapon_used  count
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  42705
# 1                     UNKNOWN WEAPON/OTHER WEAPON  21340
# 2                                        HAND GUN  18535
# 3                KNIFE WITH BLADE 6INCHES OR LESS   6645
# 4                           SEMI-AUTOMATIC PISTOL   6625
# 5                                     OTHER KNIFE   5655
# 6                                 UNKNOWN FIREARM   5293
# 7                               MACE/PEPPER SPRAY   3644
# 8                                   VERBAL THREAT   3184
# 9                                         VEHICLE   3002

# %%
sns.barplot(x="weapon_used", y="count", data=weapon_data)
plt.xticks (rotation = 90)
plt.xlabel ("")
plt.ylabel("")
plt.title("Types of weapons most commonly used in serious crimes")

plt.show()

# %%
data.sample(2)
# Out:
#        notifiction_date crime_date  accident_time      area    level  \
# 916954       2024-12-05 2024-12-05           1550   Central  Serious
# 545772       2022-04-29 2022-04-25            900  Wilshire  Serious
#
#                          description_crime  vict_age vict_sex vict_descent  \
# 916954  THEFT PLAIN - PETTY ($950 & UNDER)        26     Male            W
# 545772                    VEHICLE - STOLEN        28     Male            X
#
#        weapon_used       status                                 location  \
# 916954     Unknown  Invest Cont   800 N  ALAMEDA                      ST
# 545772     Unknown  Invest Cont  4500 W  WASHINGTON                   BL
#
#        range_time
# 916954    Evening
# 545772  Afternoon

# %%
# النطاق الربيعي (IQR - Interquartile Range)

# Q1 = data["vict_age"].quantile(0.25)
# Q3 = data["vict_age"].quantile(0.75)
# IQR = Q3 - Q1

# outliers = data[(data["vict_age"] < Q1 - 1.5 * IQR) | (data["vict_age"] > Q3 + 1.5 * IQR)]
# outliers

# -------------2-------------------------
# (طريقة للقيم المعقدة)(خوارزميات تعلم آلي

# from sklearn.ensemble import IsolationForest

# model = IsolationForest(contamination=0.05)
# data["vict_age"] = model.fit_predict(data[["vict_age"]])
# outliers = data[data["vict_age"] == -1]

# %%
sns.boxplot(x=data["vict_age"])
# Out:
# <Axes: xlabel='vict_age'>

# %%
data["vict_age"].describe().round(2)
# Out:
# count    1000046.00
# mean          36.46
# std           14.28
# min           -4.00
# 25%           28.00
# 50%           30.00
# 75%           44.00
# max          120.00
# Name: vict_age, dtype: float64

# %%
Q1 = data["vict_age"].quantile(0.25)
Q3 = data["vict_age"].quantile(0.75)
IQR = Q3 - Q1

outliers = data[(data["vict_age"] < Q1 - 1.5 * IQR) | (data["vict_age"] > Q3 + 1.5 * IQR)]
outliers.shape
# Out:
# (36414, 13)

# %%
mean = round(np.mean(data["vict_age"]), 2)
print("mean of age: " , mean)
STD = round(np.std(data["vict_age"]), 2)
print("Standard deviation of age: " , STD)

outliers1 = data[data["vict_age"] > mean + 2 * STD]
outliers2 = data[data["vict_age"] < mean - 2 * STD]



# outliers1 = data["vict_age"] > mean + 2 * STD
# outliers2 = data["vict_age"] < mean - 2 * STD
# outliers = data[outliers1 | outliers2]
# outliers.shape
# Out:
# mean of age:  36.46
# Standard deviation of age:  14.28

# %%
print("outliers start from this Value: ", outliers1.sort_values(by="vict_age")["vict_age"].iloc[0],
      "\n and this Value: ", outliers2.sort_values(by="vict_age")["vict_age"].iloc[-1],
      "\n but part 1 of data starts from this Value: (0) becuse there are no negative ages values" )
# Out:
# outliers start from this Value:  66
#  and this Value:  7
#  but part 1 of data starts from this Value: (0) becuse there are no negative ages values

# %%
print("mean of age: ", round(np.mean(data[data["vict_age"] > 0]["vict_age"]), 1))
data.loc[(data["vict_age"] > 66) | (data["vict_age"] < 0), "vict_age"] = round(np.mean(data[data["vict_age"] > 0]["vict_age"]), 1)
# Out:
# mean of age:  36.5

# %%
print("outliers after Dealing:", data[(data["vict_age"] > 66) | (data["vict_age"] < 0)].shape[0])
# Out:
# outliers after Dealing: 0

# %%
sns.boxplot(x=data["vict_age"])
# Out:
# <Axes: xlabel='vict_age'>

# %%
data[(data["vict_age"] >= 60) | (data["vict_age"] <= 11)][["vict_age" , "description_crime"]]
# Out:
#          vict_age                                description_crime
# 4            63.0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 50           11.0          CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT
# 52           61.0                                         BURGLARY
# 71           62.0          LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 84           60.0                         BATTERY - SIMPLE ASSAULT
# ...           ...                                              ...
# 1004847      60.0                         BATTERY - SIMPLE ASSAULT
# 1004879      62.0                                THEFT OF IDENTITY
# 1004931       4.0                   CHILD NEGLECT (SEE 300 W.I.C.)
# 1004981       4.0                   CHILD NEGLECT (SEE 300 W.I.C.)
# 1004987      11.0                   CHILD NEGLECT (SEE 300 W.I.C.)
#
# [52903 rows x 2 columns]

# %%
data['ages_ranges'] = pd.cut(data['vict_age'],bins = [0,10,18,30,45,100],
                                labels = ['babies','teenager','Adults','MiddleAged','Aged'])
data['ages_ranges'].value_counts()
# Out:
# ages_ranges
# Adults        477136
# MiddleAged    300951
# Aged          190538
# teenager       26167
# babies          5254
# Name: count, dtype: int64

# %%
ages = data.groupby("ages_ranges")["level"].value_counts().reset_index(name="count")
ages
# Out:
#   ages_ranges        level   count
# 0      babies  LessSerious    4083
# 1      babies      Serious    1171
# 2    teenager  LessSerious   15984
# 3    teenager      Serious   10183
# 4      Adults      Serious  332024
# 5      Adults  LessSerious  145112
# 6  MiddleAged      Serious  158114
# 7  MiddleAged  LessSerious  142837
# 8        Aged      Serious   98096
# 9        Aged  LessSerious   92442

# %%
g = sns.catplot(
    kind="bar",
    x="ages_ranges",
    y= "count",
    hue="level",
    data=ages,
    errorbar="sd",
    palette="dark",
    alpha=0.6,
    height=6,
    order=["babies", "teenager", "Adults", "MiddleAged", "Aged"]
)

plt.xlabel("ages")
plt.ylabel("")
plt.title("Relationship between age and level")
plt.show()

# %%
data.head()
# Out:
#   notifiction_date crime_date  accident_time         area        level  \
# 0       2021-04-11 2020-11-07            845  N Hollywood  LessSerious
# 1       2020-10-21 2020-10-18           1845  N Hollywood      Serious
# 2       2024-12-10 2020-10-30           1240     Van Nuys  LessSerious
# 3       2020-12-24 2020-12-24           1310     Wilshire      Serious
# 4       2020-10-03 2020-09-29           1830      Pacific      Serious
#
#                                    description_crime  vict_age vict_sex  \
# 0                                  THEFT OF IDENTITY      31.0     Male
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT      32.0     Male
# 2                                  THEFT OF IDENTITY      30.0     Male
# 3  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...      47.0   Female
# 4    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)      63.0     Male
#
#   vict_descent                       weapon_used       status  \
# ...

# %%
data["vict_descent"].unique()
# Out:
# array(['Hispanic', 'White', 'Asian', 'Black', 'Unknown', 'Other',
#        'Chinese', 'Japanese', 'Vietnamese', 'Korean', 'Filipino',
#        'American Indian', 'Asian Indian', 'Laotian', 'Guamanian',
#        'Pacific Islander', 'Cambodian', 'Hawaiian', 'Samoan'],
#       dtype=object)

# %%
data["vict_descent"] = data["vict_descent"].replace({
        'O': 'Other',
        'X': 'Unknown',
        'H': 'Hispanic',
        'B': 'Black',
        'W': 'White',
        'A': 'Asian',
        'K': 'Korean',
        'C': 'Chinese',
        'J': 'Japanese',
        'F': 'Filipino',
        'I': 'American Indian',
        'V': 'Vietnamese',
        'S': 'Samoan',
        'P': 'Pacific Islander',
        'Z': 'Asian Indian',
        'G': 'Guamanian',
        'U': 'Hawaiian',
        'D': 'Cambodian',
        'L': 'Laotian',
        '-': 'Not Specified',
        np.nan: 'Missing'
    })
data["vict_descent"].value_counts()
# Out:
# vict_descent
# Hispanic            295629
# Unknown             248279
# White               201028
# Black               135484
# Other                77674
# Asian                21325
# Korean                5987
# Filipino              4836
# Chinese               4628
# Japanese              1583
# Vietnamese            1195
# American Indian       1014
# Asian Indian           576
# Pacific Islander       288
# Hawaiian               220
# Cambodian               91
# Laotian                 77
# Guamanian               74
# Samoan                  58
# Name: count, dtype: int64

# %%
originals = data[data["vict_descent"].isin(["American Indian", "Hawaiian", "Samoan", "Guamanian", "Pacific Islander"])]
originals.sample()
# Out:
#        notifiction_date crime_date  accident_time     area    level  \
# 708676       2023-11-02 2023-11-02            100  Central  Serious
#
#                                         description_crime  vict_age vict_sex  \
# 708676  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...      18.0     Male
#
#            vict_descent weapon_used       status  \
# 708676  American Indian     Unknown  Invest Cont
#
#                                       location range_time ages_ranges
# 708676  800 N  VIGNES                       ST    Morning    teenager

# %%
new_originals = originals.groupby("vict_descent")["level"].value_counts().reset_index(name="count")
new_originals
# Out:
#        vict_descent        level  count
# 0   American Indian      Serious    669
# 1   American Indian  LessSerious    345
# 2         Guamanian      Serious     45
# 3         Guamanian  LessSerious     29
# 4          Hawaiian      Serious    158
# 5          Hawaiian  LessSerious     62
# 6  Pacific Islander      Serious    181
# 7  Pacific Islander  LessSerious    107
# 8            Samoan      Serious     31
# 9            Samoan  LessSerious     27

# %%
g = sns.catplot(
    kind="bar",
    x="vict_descent",
    y= "count",
    hue="level",
    data=new_originals,
    errorbar="sd",
    palette="dark",
    alpha=0.6,
    height=6,
    aspect=2
)

plt.xlabel("vict_descent")
plt.ylabel("")
plt.show()

# %%
originals_without = originals["vict_descent"].value_counts().reset_index(name="count")
originals_without
# Out:
#        vict_descent  count
# 0   American Indian   1014
# 1  Pacific Islander    288
# 2          Hawaiian    220
# 3         Guamanian     74
# 4            Samoan     58

# %%
# !pip install squarify

# %%
import matplotlib.pyplot as plt
import squarify
labels = [f"{descent}\n{count}" for descent, count in zip(originals_without["vict_descent"], originals_without["count"])]

squarify.plot(sizes= originals_without["count"], label= labels, alpha=.8 )
plt.axis('off')

plt.show()

# %%
not_originals= data.query("vict_descent not in ['American Indian', 'Hawaiian', 'Samoan', 'Guamanian', 'Pacific Islander']")
not_originals.head()
# Out:
#   notifiction_date crime_date  accident_time         area        level  \
# 0       2021-04-11 2020-11-07            845  N Hollywood  LessSerious
# 1       2020-10-21 2020-10-18           1845  N Hollywood      Serious
# 2       2024-12-10 2020-10-30           1240     Van Nuys  LessSerious
# 3       2020-12-24 2020-12-24           1310     Wilshire      Serious
# 4       2020-10-03 2020-09-29           1830      Pacific      Serious
#
#                                    description_crime  vict_age vict_sex  \
# 0                                  THEFT OF IDENTITY      31.0     Male
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT      32.0     Male
# 2                                  THEFT OF IDENTITY      30.0     Male
# 3  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...      47.0   Female
# 4    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)      63.0     Male
#
#   vict_descent                       weapon_used       status  \
# ...

# %%
new_notoriginals = originals.groupby("vict_descent")["level"].value_counts().reset_index(name="count")
new_notoriginals
# Out:
#        vict_descent        level  count
# 0   American Indian      Serious    669
# 1   American Indian  LessSerious    345
# 2         Guamanian      Serious     45
# 3         Guamanian  LessSerious     29
# 4          Hawaiian      Serious    158
# 5          Hawaiian  LessSerious     62
# 6  Pacific Islander      Serious    181
# 7  Pacific Islander  LessSerious    107
# 8            Samoan      Serious     31
# 9            Samoan  LessSerious     27

# %%
g = sns.catplot(
    kind="bar",
    x="vict_descent",
    y= "count",
    hue="level",
    data=new_notoriginals,
    errorbar="sd",
    palette="dark",
    alpha=0.6,
    height=6,
    aspect=2
)

plt.xlabel("vict_descent")
plt.ylabel("")
plt.show()

# %%
notoriginals_without = originals["vict_descent"].value_counts().reset_index(name="count")
notoriginals_without
# Out:
#        vict_descent  count
# 0   American Indian   1014
# 1  Pacific Islander    288
# 2          Hawaiian    220
# 3         Guamanian     74
# 4            Samoan     58

# %%
labels = [f"{descent}\n{count}" for descent, count in zip(notoriginals_without["vict_descent"], notoriginals_without["count"])]

plt.figure(figsize=(20, 10))
squarify.plot(sizes= notoriginals_without["count"], label= labels, alpha=.8,  )

plt.axis('off')
plt.show()
